# %%
# !unzip dataset/zip/14984667.zip -d dataset/uzip/
# Out:
# Archive:  dataset/zip/14984667.zip
#  extracting: dataset/uzip/Videos.zip
#  extracting: dataset/uzip/PDFEinfo.csv
#  extracting: dataset/uzip/IMU.zip
