# %%
import subprocess

# %%
from pathlib import Path

# %%
Path.cwd().parent
# Out:
# PosixPath('/home/workstation-p/Downloads/Projects/FYDP')

# %%
data_dir=Path.cwd().parent/"dataset"
print(data_dir)
# Out:
# /home/workstation-p/Downloads/Projects/FYDP/dataset

# %%
unzip_data_dir=data_dir/"uzip"
print(unzip_data_dir)
unzip_data=list(unzip_data_dir.glob("*.zip"))
print(unzip_data)
# Out:
# /home/workstation-p/Downloads/Projects/FYDP/dataset/uzip
# [PosixPath('/home/workstation-p/Downloads/Projects/FYDP/dataset/uzip/Videos.zip'), PosixPath('/home/workstation-p/Downloads/Projects/FYDP/dataset/uzip/IMU.zip')]

# %%
subprocess.run(["unzip",unzip_data[0],"-d",data_dir/"video_data"])
# Out:
# Archive:  /home/workstation-p/Downloads/Projects/FYDP/dataset/uzip/Videos.zip
#   inflating: /home/workstation-p/Downloads/Projects/FYDP/dataset/video_data/Videos/PDFE01_1.mp4
#   inflating: /home/workstation-p/Downloads/Projects/FYDP/dataset/video_data/Videos/PDFE01_2.mp4
#   inflating: /home/workstation-p/Downloads/Projects/FYDP/dataset/video_data/Videos/PDFE02_1.mp4
#   inflating: /home/workstation-p/Downloads/Projects/FYDP/dataset/video_data/Videos/PDFE03_1.mp4
#   inflating: /home/workstation-p/Downloads/Projects/FYDP/dataset/video_data/Videos/PDFE03_2.mp4
#   inflating: /home/workstation-p/Downloads/Projects/FYDP/dataset/video_data/Videos/PDFE03_3.mp4
#   inflating: /home/workstation-p/Downloads/Projects/FYDP/dataset/video_data/Videos/PDFE04_1.mp4
#   inflating: /home/workstation-p/Downloads/Projects/FYDP/dataset/video_data/Videos/PDFE05_1.mp4
#   inflating: /home/workstation-p/Downloads/Projects/FYDP/dataset/video_data/Videos/PDFE05_2.mp4
# ...

# %%
subprocess.run(["unzip",unzip_data[1],"-d",data_dir/"imu_data"])
# Out:
# Archive:  /home/workstation-p/Downloads/Projects/FYDP/dataset/uzip/IMU.zip
#   inflating: /home/workstation-p/Downloads/Projects/FYDP/dataset/imu_data/IMU/SUB01_1.csv
#   inflating: /home/workstation-p/Downloads/Projects/FYDP/dataset/imu_data/IMU/SUB01_1.txt
#   inflating: /home/workstation-p/Downloads/Projects/FYDP/dataset/imu_data/IMU/SUB01_2.csv
#   inflating: /home/workstation-p/Downloads/Projects/FYDP/dataset/imu_data/IMU/SUB01_2.txt
#   inflating: /home/workstation-p/Downloads/Projects/FYDP/dataset/imu_data/IMU/SUB01_standing.csv
#   inflating: /home/workstation-p/Downloads/Projects/FYDP/dataset/imu_data/IMU/SUB01_standing.txt
#   inflating: /home/workstation-p/Downloads/Projects/FYDP/dataset/imu_data/IMU/SUB02_1.csv
#   inflating: /home/workstation-p/Downloads/Projects/FYDP/dataset/imu_data/IMU/SUB02_1.txt
#   inflating: /home/workstation-p/Downloads/Projects/FYDP/dataset/imu_data/IMU/SUB02_standing.csv
# ...
